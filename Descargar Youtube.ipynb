# %% [markdown]
# Instalación de pytube: Asegúrate de tener Python 3.6 o superior instalado

# %%
pip install pytube
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Curso Diseño de Base de Datos

# %% [markdown]
# Descargar un video: Puedes descargar un video de YouTube utilizando el siguiente código:

# %%
from pytube import YouTube

# URL del video que deseas descargar
video_url = "https://youtu.be/HXE169-n5pM?si=t7J0utHNxrzWMXTk"

# Crea un objeto YouTube con la URL
yt = YouTube(video_url)

# Descarga el video en la máxima resolución progresiva
yt.streams.get_highest_resolution().download()
# Out:
# '/content/Curso Diseño de Bases de Datos - jonmircha.mp4'

# %% [markdown]
# Curso Git Hub

# %%
from pytube import YouTube

# URL del video que deseas descargar
video_url = "https://youtu.be/suzMNqDQiyU?si=S8x1T0x9nLm71Y-8"

# Crea un objeto YouTube con la URL
yt = YouTube(video_url)

# Descarga el video en la máxima resolución progresiva
yt.streams.get_highest_resolution().download()
# Out:
# '/content/Curso Git & GitHub - jonmircha.mp4'

# %% [markdown]
# Curso Modelado de Datos

# %%
from pytube import YouTube

# URL del video que deseas descargar
video_url = "https://youtu.be/aFgHVE_Y_YU?si=hJZJZz-c9ZghZ-7-"

# Crea un objeto YouTube con la URL
yt = YouTube(video_url)

# Descarga el video en la máxima resolución progresiva
yt.streams.get_highest_resolution().download()
# Out:
# '/content/Curso Modelado de Bases de Datos - jonmircha.mp4'

# %% [markdown]
# Curso de SQL

# %%
from pytube import YouTube

# URL del video que deseas descargar
video_url = "https://youtu.be/UAuZvxPTi58?si=5NQBEMye4FFfpIvd"

# Crea un objeto YouTube con la URL
yt = YouTube(video_url)

# Descarga el video en la máxima resolución progresiva
yt.streams.get_highest_resolution().download()
# Out:
# '/content/Curso SQL - jonmircha.mp4'

# %% [markdown]
# Curso de Markdown

# %%
from pytube import YouTube

# URL del video que deseas descargar
video_url = "https://youtu.be/FlsoBiteuPM?si=U2iU97mYzaJ_7iwS"

# Crea un objeto YouTube con la URL
yt = YouTube(video_url)

# Descarga el video en la máxima resolución progresiva
yt.streams.get_highest_resolution().download()
# Out:
# '/content/Curso Markdown - jonmircha.mp4'

# %% [markdown]
# Descargar un video de una lista de reproducción: Si deseas descargar todos los videos de una lista de reproducción, puedes hacerlo de la siguiente manera:

# %%
from pytube import Playlist

# Get the playlist URL
playlist_url = "https://youtube.com/playlist?list=PLdxuOh58KNA6_o3VqvY-i2gUSfmptxzuT&si=EJQv7tCR8i20VmcP"

# Create a Playlist object
playlist = Playlist(playlist_url)

# Download all videos in the playlist
for video in playlist.videos:
    video.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first().download()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-a962315d050e> in <cell line: 10>()
#       9 # Download all videos in the playlist
#      10 for video in playlist.videos:
# ---> 11     video.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first().download()
#
# /usr/local/lib/python3.10/dist-packages/pytube/streams.py in download(self, output_path, filename, filename_prefix, skip_existing, timeout, max_retries)
#     312         with open(file_path, "wb") as fh:
#     313             try:
# --> 314                 for chunk in request.stream(
#     315                     self.url,
#     316                     timeout=timeout,
#
# /usr/local/lib/python3.10/dist-packages/pytube/request.py in stream(url, timeout, max_retries)
#     187                 logger.error(e)
#     188         while True:
# ...
